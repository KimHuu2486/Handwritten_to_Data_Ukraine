# %%
# =========================================================
# CELL 1: CÀI ĐẶT & CẤU HÌNH ĐƯỜNG DẪN
# =========================================================
# !pip install -q "huggingface_hub>=0.26.2" pyyaml

# %%
# !rm -rf /kaggle/working/layout_data/rukopys_v3

# %%
import os
import json
import random
import shutil
import re
from pathlib import Path
from collections import Counter, defaultdict
from tqdm import tqdm
import yaml
from huggingface_hub import hf_hub_download

# --- INPUT DATA ---
GOLD_DIR = Path("/kaggle/input/datasets/notpitomon/htd-better-gold-dataset/BetterGoldScanned V1/train")
SILVER_DIR = Path("None")

# --- OUTPUT YOLO DATASET ---
OUT_ROOT = Path("/kaggle/working/layout_data/rukopys_v3")
if OUT_ROOT.exists():
    shutil.rmtree(OUT_ROOT)

(OUT_ROOT / "images").mkdir(parents=True, exist_ok=True)
(OUT_ROOT / "labels").mkdir(parents=True, exist_ok=True)

# TUYỆT ĐỐI GHI NHỚ:
# RUKOPYS Gold + Silver rare trong notebook này đều dùng bbox gốc dạng COCO: [x, y, w, h]
# Không được viết lại parser xyxy nữa.
BBOX_FORMAT = "xyxy"

# --- CLASS MAP ---
TYPE2ID = {
    "handwritten": 0,
    "printed": 1,
    "formula": 2,
    "table": 3,
    "annotation": 4,
    "image": 5,
    "graph": 6,
}

ID2TYPE = {v: k for k, v in TYPE2ID.items()}

# --- SPLIT / SAMPLING CONFIG ---
VAL_RATIO = 0.15
SEED = 42

# Silver rare là bổ trợ, không được lấn át Gold
USE_SILVER = False
MAX_SILVER_IMAGES = 1200   # có thể giảm xuống 600-1000 nếu muốn bảo thủ hơn

random.seed(SEED)

print("✅ Config xong.")
print("GOLD_DIR   =", GOLD_DIR)
print("SILVER_DIR =", SILVER_DIR)
print("OUT_ROOT   =", OUT_ROOT)
print("BBOX_FORMAT =", BBOX_FORMAT)
# Out:
# ✅ Config xong.
# GOLD_DIR   = /kaggle/input/datasets/notpitomon/htd-better-gold-dataset/BetterGoldScanned V1/train
# SILVER_DIR = None
# OUT_ROOT   = /kaggle/working/layout_data/rukopys_v3
# BBOX_FORMAT = xyxy

# %%
# =========================================================
# CELL 2: HÀM HỖ TRỢ CHUYỂN BBOX & IO (XYXY -> YOLO)
# =========================================================
def safe_link(src: Path, dst: Path):
    if dst.exists():
        return
    try:
        os.symlink(src, dst)
    except OSError:
        shutil.copy2(src, dst)

def clamp_xyxy(x1, y1, x2, y2, img_w, img_h):
    x1 = max(0.0, min(float(x1), float(img_w - 1)))
    y1 = max(0.0, min(float(y1), float(img_h - 1)))
    x2 = max(0.0, min(float(x2), float(img_w - 1)))
    y2 = max(0.0, min(float(y2), float(img_h - 1)))
    return x1, y1, x2, y2

def xyxy_to_yolo(x1, y1, x2, y2, img_w, img_h):
    w = x2 - x1
    h = y2 - y1
    cx = (x1 + w / 2.0) / img_w
    cy = (y1 + h / 2.0) / img_h
    nw = w / img_w
    nh = h / img_h
    return cx, cy, nw, nh

def region_to_yolo_line(region, img_w, img_h):
    t = region.get("type")
    if t not in TYPE2ID:
        return None

    bbox = region.get("bbox")
    if not bbox or len(bbox) != 4:
        return None

    # Đọc theo format xyxy
    x1, y1, x2, y2 = map(float, bbox)
    x1, y1, x2, y2 = clamp_xyxy(x1, y1, x2, y2, img_w, img_h)

    if (x2 - x1) <= 1 or (y2 - y1) <= 1:
        return None

    cx, cy, nw, nh = xyxy_to_yolo(x1, y1, x2, y2, img_w, img_h)

    if not (0 <= cx <= 1 and 0 <= cy <= 1 and 0 < nw <= 1 and 0 < nh <= 1):
        return None

    return f"{TYPE2ID[t]} {cx:.6f} {cy:.6f} {nw:.6f} {nh:.6f}"

def load_metadata(meta_path: Path):
    rows = []
    with open(meta_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if line:
                rows.append(json.loads(line))
    return rows

def get_base_name(fname: str):
    name = Path(fname).name
    name = re.sub(r"_aug\d+", "", name)
    return name

# %%
# =========================================================
# CELL 3: LOAD METADATA
# =========================================================
gold_metadata = load_metadata(GOLD_DIR / "metadata.jsonl")
print(f"Gold records: {len(gold_metadata)}")

if USE_SILVER and (SILVER_DIR / "metadata.jsonl").exists():
    silver_metadata = load_metadata(SILVER_DIR / "metadata.jsonl")
    print(f"Silver records: {len(silver_metadata)}")
else:
    silver_metadata = []
    print("Silver records: 0")

print("\n✅ Xác nhận cứng: Gold và Silver đều dùng bbox format COCO = [x, y, w, h]")
print("✅ Toàn bộ pipeline convert label sẽ đọc bbox theo COCO rồi đổi sang YOLO normalized xywh")
# Out:
# Gold records: 2460
# Silver records: 0
#
# ✅ Xác nhận cứng: Gold và Silver đều dùng bbox format COCO = [x, y, w, h]
# ✅ Toàn bộ pipeline convert label sẽ đọc bbox theo COCO rồi đổi sang YOLO normalized xywh

# %%
# =========================================================
# CELL 4: CHIA GOLD TRAIN/VAL + CHỌN SILVER BỔ TRỢ
# =========================================================
base_names = sorted({get_base_name(d["file_name"]) for d in gold_metadata})
random.shuffle(base_names)

split_idx = int(len(base_names) * (1 - VAL_RATIO))
train_bases = set(base_names[:split_idx])
val_bases = set(base_names[split_idx:])

print(f"Gold base images: {len(base_names)}")
print(f"Train bases: {len(train_bases)} | Val bases: {len(val_bases)}")

def count_classes_in_record(d):
    c = Counter()
    for r in d.get("regions", []):
        t = r.get("type")
        if t in TYPE2ID:
            c[t] += 1
    return c

selected_silver = []

if silver_metadata and USE_SILVER:
    scored = []
    for d in silver_metadata:
        regions = d.get("regions", [])
        if not regions:
            continue

        c = count_classes_in_record(d)
        total = sum(c.values())
        if total == 0:
            continue

        head = c["handwritten"] + c["formula"]
        tail = c["image"] + c["graph"]
        mid  = c["printed"] + c["table"] + c["annotation"]

        rare_ratio = tail / total
        dominant_ratio = head / total

        score = (
            c["graph"] * 5.0 +
            c["image"] * 4.0 +
            c["table"] * 1.5 +
            c["annotation"] * 1.0 +
            rare_ratio * 10.0 -
            dominant_ratio * 6.0 -
            max(0, c["handwritten"] - 20) * 0.15 -
            max(0, c["formula"] - 10) * 0.20
        )

        # Chặn các ảnh nhìn như head-class dominant nhưng chỉ có rare tượng trưng
        if dominant_ratio >= 0.8 and tail <= 1:
            continue

        scored.append((score, d, c))

    scored.sort(key=lambda x: x[0], reverse=True)
    selected_silver = [x[1] for x in scored[:MAX_SILVER_IMAGES]]

    agg = Counter()
    for _, _, c in scored[:MAX_SILVER_IMAGES]:
        agg.update(c)

    print(f"Selected silver images: {len(selected_silver)}")
    print("Silver selected box distribution:")
    for cls, cnt in sorted(agg.items(), key=lambda kv: kv[1]):
        print(f"  - {cls}: {cnt}")
else:
    print("Không dùng silver bổ trợ.")
# Out:
# Gold base images: 2120
# Train bases: 1802 | Val bases: 318
# Không dùng silver bổ trợ.

# %%
# =========================================================
# CELL 5: BUILD YOLO DATASET
# =========================================================
train_files = []
val_files = []

gold_train_count = 0
gold_val_count = 0
silver_train_count = 0

bad_records = 0
class_counter_train = Counter()
class_counter_val = Counter()

def process_record_to_yolo(d, image_root: Path, split: str):
    global bad_records

    fname = Path(d["file_name"]).name
    img_w, img_h = d["image_width"], d["image_height"]
    regions = d.get("regions", [])

    if not regions:
        bad_records += 1
        return False

    in_path = image_root / fname
    if not in_path.exists():
        bad_records += 1
        return False

    out_img = OUT_ROOT / "images" / fname
    safe_link(in_path, out_img)

    label_lines = []
    local_counter = Counter()

    for r in regions:
        line = region_to_yolo_line(r, img_w, img_h)
        if line is not None:
            label_lines.append(line)
            local_counter[r["type"]] += 1

    if not label_lines:
        bad_records += 1
        return False

    with open(OUT_ROOT / "labels" / f"{Path(fname).stem}.txt", "w", encoding="utf-8") as f:
        f.write("\n".join(label_lines))

    if split == "train":
        train_files.append(fname)
        class_counter_train.update(local_counter)
    else:
        val_files.append(fname)
        class_counter_val.update(local_counter)

    return True

# -----------------------
# GOLD
# -----------------------
for d in tqdm(gold_metadata, desc="Processing GOLD"):
    fname = Path(d["file_name"]).name
    base = get_base_name(fname)
    is_val = base in val_bases

    # Không cho ảnh augment vào val
    if is_val and "_aug" in fname:
        continue

    split = "val" if is_val else "train"
    ok = process_record_to_yolo(d, GOLD_DIR / "images", split)

    if ok:
        if split == "train":
            gold_train_count += 1
        else:
            gold_val_count += 1

# -----------------------
# SILVER rare supplement
# -----------------------
for d in tqdm(selected_silver, desc="Processing SILVER rare supplement"):
    ok = process_record_to_yolo(d, SILVER_DIR / "images", "train")
    if ok:
        silver_train_count += 1

random.shuffle(train_files)

print("\n✅ Build dataset xong.")
print(f"Gold train images used: {gold_train_count}")
print(f"Gold val images used:   {gold_val_count}")
print(f"Silver train images used: {silver_train_count}")
print(f"Bad/Skipped records: {bad_records}")

print("\nTrain class distribution:")
for cls, cnt in sorted(class_counter_train.items(), key=lambda kv: kv[1]):
    print(f"  - {cls}: {cnt}")

print("\nVal class distribution:")
for cls, cnt in sorted(class_counter_val.items(), key=lambda kv: kv[1]):
    print(f"  - {cls}: {cnt}")
# Out:
# Processing GOLD: 100%|██████████| 2460/2460 [00:07<00:00, 325.48it/s]
# Processing SILVER rare supplement: 0it [00:00, ?it/s]
# ✅ Build dataset xong.
# Gold train images used: 2070
# Gold val images used:   257
# Silver train images used: 0
# Bad/Skipped records: 1
#
# Train class distribution:
#   - graph: 140
#   - table: 496
#   - image: 636
#   - annotation: 1009
#   - formula: 3289
#   - printed: 4848
#   - handwritten: 23600
#
# Val class distribution:
#   - graph: 7
#   - table: 59
#   - image: 60
#   - annotation: 146
#   - formula: 458
#   - printed: 599
#   - handwritten: 3669

# %%
# =========================================================
# CELL 6: GHI train.txt / val.txt / yaml
# =========================================================
train_txt = OUT_ROOT / "train.txt"
val_txt   = OUT_ROOT / "val.txt"

with open(train_txt, "w", encoding="utf-8") as f:
    for fname in train_files:
        f.write(str(OUT_ROOT / "images" / fname) + "\n")

with open(val_txt, "w", encoding="utf-8") as f:
    for fname in val_files:
        f.write(str(OUT_ROOT / "images" / fname) + "\n")

yaml_path = "/kaggle/working/rukopys_dataset_v3.yaml"
data_config = {
    "path": str(OUT_ROOT),
    "train": "train.txt",
    "val": "val.txt",
    "nc": 7,
    "names": ["handwritten", "printed", "formula", "table", "annotation", "image", "graph"]
}

with open(yaml_path, "w", encoding="utf-8") as f:
    yaml.dump(data_config, f, sort_keys=False)

# Giữ nguyên bản vá hoang dã .yaml.yaml
shutil.copy(yaml_path, yaml_path + ".yaml")

print(f"Train images: {len(train_files)}")
print(f"Val images:   {len(val_files)}")
print("YAML written:", yaml_path)
print("YAML duplicate:", yaml_path + ".yaml")
# Out:
# Train images: 2070
# Val images:   257
# YAML written: /kaggle/working/rukopys_dataset_v3.yaml
# YAML duplicate: /kaggle/working/rukopys_dataset_v3.yaml.yaml

# %%
# =========================================================
# CELL 7: SETUP DOCLAYOUT-YOLO + PATCH
# =========================================================
import sys
import os
from types import ModuleType

# %cd /kaggle/working

if not os.path.exists("DocLayout-YOLO"):
    # !git clone --depth 1 https://github.com/opendatalab/DocLayout-YOLO.git

# %cd /kaggle/working/DocLayout-YOLO
# !pip install -q -e .

# --- Patch check_amp ---
checks_file = "/kaggle/working/DocLayout-YOLO/doclayout_yolo/utils/checks.py"
if os.path.exists(checks_file):
    with open(checks_file, "r", encoding="utf-8") as f:
        code = f.read()
    if "def check_amp(model):" in code and "return True" not in code.split("def check_amp(model):")[1][:40]:
        code = code.replace("def check_amp(model):", "def check_amp(model):\n    return True\n")
        with open(checks_file, "w", encoding="utf-8") as f:
            f.write(code)
        print("✅ Patched check_amp()")

# --- Patch strip_optimizer / torch.load for PyTorch 2.6 ---
torch_utils_file = "/kaggle/working/DocLayout-YOLO/doclayout_yolo/utils/torch_utils.py"
if os.path.exists(torch_utils_file):
    with open(torch_utils_file, "r", encoding="utf-8") as f:
        code = f.read()

    old_load = 'x = torch.load(f, map_location=torch.device("cpu"))'
    new_load = 'x = torch.load(f, map_location=torch.device("cpu"), weights_only=False)'

    if old_load in code:
        code = code.replace(old_load, new_load)
        with open(torch_utils_file, "w", encoding="utf-8") as f:
            f.write(code)
        print("✅ Patched strip_optimizer torch.load(..., weights_only=False)")

# --- Patch G2L_CRM Fuse Bug ---
g2l_file = "/kaggle/working/DocLayout-YOLO/doclayout_yolo/nn/modules/g2l_crm.py"
if os.path.exists(g2l_file):
    with open(g2l_file, "r", encoding="utf-8") as f:
        code = f.read()
    if "bn = self.dcv.bn" in code:
        code = code.replace("bn = self.dcv.bn", "bn = getattr(self.dcv, 'bn', None)")
        with open(g2l_file, "w", encoding="utf-8") as f:
            f.write(code)
        print("✅ Patched G2L_CRM for fuse compatibility")

# --- Patch NumPy 2.0 trapz bug ---
metrics_file = "/kaggle/working/DocLayout-YOLO/doclayout_yolo/utils/metrics.py"
if os.path.exists(metrics_file):
    with open(metrics_file, "r", encoding="utf-8") as f:
        code = f.read()
    if "np.trapz(" in code:
        code = code.replace("np.trapz(", "np.trapezoid(")
        with open(metrics_file, "w", encoding="utf-8") as f:
            f.write(code)
        print("✅ Patched np.trapz to np.trapezoid in metrics.py")

# !pip uninstall ray -y -q

if "doclayout_yolo.utils.callbacks.hub" not in sys.modules:
    dummy_hub = ModuleType("doclayout_yolo.utils.callbacks.hub")
    dummy_hub.callbacks = {}
    sys.modules["doclayout_yolo.utils.callbacks.hub"] = dummy_hub

print("✅ DocLayout-YOLO setup xong.")
# Out:
# /kaggle/working
# Cloning into 'DocLayout-YOLO'...
# remote: Enumerating objects: 277, done.
# remote: Counting objects: 100% (277/277), done.
# remote: Compressing objects: 100% (234/234), done.
# remote: Total 277 (delta 41), reused 237 (delta 40), pack-reused 0 (from 0)
# Receiving objects: 100% (277/277), 10.79 MiB | 29.06 MiB/s, done.
# Resolving deltas: 100% (41/41), done.
# /kaggle/working/DocLayout-YOLO
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 94.8 MB/s eta 0:00:00
#   Building editable for doclayout_yolo (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.
# ✅ Patched check_amp()
# ✅ Patched strip_optimizer torch.load(..., weights_only=False)
# ✅ Patched G2L_CRM for fuse compatibility
# ✅ Patched np.trapz to np.trapezoid in metrics.py
# ✅ DocLayout-YOLO setup xong.

# %%
# =========================================================
# CELL 8: TẢI PRETRAIN
# =========================================================
CKPT_PATH = hf_hub_download(
    repo_id="juliozhao/DocLayout-YOLO-DocStructBench",
    filename="doclayout_yolo_docstructbench_imgsz1024.pt"
)

print("✅ Pretrain checkpoint:", CKPT_PATH)
# Out:
# doclayout_yolo_docstructbench_imgsz1024.(…):   0%|          | 0.00/40.7M [00:00<?, ?B/s]
# ✅ Pretrain checkpoint: /root/.cache/huggingface/hub/models--juliozhao--DocLayout-YOLO-DocStructBench/snapshots/8c3299a30b8ff29a1503c4431b035b93220f7b11/doclayout_yolo_docstructbench_imgsz1024.pt

# %%
# =========================================================
# CELL 9: TRAIN (DÙNG THAM SỐ CLI THỰC SỰ ĐƯỢC HỖ TRỢ)
# =========================================================
# %cd /kaggle/working/DocLayout-YOLO

print("\n🔥 KHỞI ĐỘNG HUẤN LUYỆN V3 + MOSAIC NHẸ 🔥")

# !WANDB_MODE=disabled RAY_DISABLE_TUNE=1 python train.py \
  --data /kaggle/working/rukopys_dataset_v3.yaml \
  --model doclayout_yolo_small \
  --epoch 100 \
  --image-size 1280 \
  --batch-size 8 \
  --mosaic 0.10 \
  --project rukopys_v3_clean_gold_plus_rare_silver \
  --optimizer Adam \
  --lr0 0.001 \
  --warmup-epochs 1.0 \
  --patience 0 \
  --pretrain {CKPT_PATH} \
  --device 0,1 \
  --workers 8
# Out:
# /kaggle/working/DocLayout-YOLO
#
# 🔥 KHỞI ĐỘNG HUẤN LUYỆN V3 + MOSAIC NHẸ 🔥
# New https://pypi.org/project/doclayout_yolo/0.0.4 available 😃 Update with 'pip install -U doclayout_yolo'
# Ultralytics YOLOv0.0.2 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#                                                             CUDA:1 (Tesla T4, 14913MiB)
# engine/trainer: task=detect, mode=train, model=/root/.cache/huggingface/hub/models--juliozhao--DocLayout-YOLO-DocStructBench/snapshots/8c3299a30b8ff29a1503c4431b035b93220f7b11/doclayout_yolo_docstructbench_imgsz1024.pt, data=/kaggle/working/rukopys_dataset_v3.yaml.yaml, epochs=100, time=None, patience=0, batch=8, imgsz=1280, save=True, save_period=10, val_period=1, cache=False, device=0,1, workers=8, project=rukopys_v3_clean_gold_plus_rare_silver, name=rukopys_dataset_v3.yaml_epoch100_imgsz1280_bs8_pretrain_unknown, exist_ok=False, pretrained=True, optimizer=Adam, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=None, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=False, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.001, lrf=0.01, momentum=0.9, weight_decay=0.0005, warmup_epochs=1.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=0.1, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=rukopys_v3_clean_gold_plus_rare_silver/yolov10doclayout_yolo_small_/kaggle/working/rukopys_dataset_v3.yaml_epoch100_imgsz1280_bs8_pretrain_unknown
# 2026-06-05 06:12:53.788572: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780639974.203204      92 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780639974.327810      92 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1780639975.293099      92 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780639975.293162      92 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780639975.293169      92 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780639975.293174      92 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Overriding model.yaml nc=10 with nc=7
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  doclayout_yolo.nn.modules.conv.Conv          [3, 48, 3, 2]
#   1                  -1  1     41664  doclayout_yolo.nn.modules.conv.Conv          [48, 96, 3, 2]
#   2                  -1  2    111360  doclayout_yolo.nn.modules.block.C2f          [96, 96, 2, True]
#   3                  -1  1    166272  doclayout_yolo.nn.modules.conv.Conv          [96, 192, 3, 2]
#   4                  -1  4   1778688  doclayout_yolo.nn.modules.g2l_crm.G2L_CRM    [192, 192, 4, True, True, [1, 2, 3], 5, 'glu']
#   5                  -1  1     78720  doclayout_yolo.nn.modules.block.SCDown       [192, 384, 3, 2]
#   6                  -1  4   4737024  doclayout_yolo.nn.modules.g2l_crm.G2L_CRM    [384, 384, 4, True, True, [1, 3, 5], 3, 'glu']
#   7                  -1  1    228672  doclayout_yolo.nn.modules.block.SCDown       [384, 576, 3, 2]
#   8                  -1  4   2714112  doclayout_yolo.nn.modules.g2l_crm.G2L_CRM    [576, 576, 4, True, False]
#   9                  -1  1    831168  doclayout_yolo.nn.modules.block.SPPF         [576, 576, 5]
#  10                  -1  1   1253088  doclayout_yolo.nn.modules.block.PSA          [576, 576]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  doclayout_yolo.nn.modules.conv.Concat        [1]
#  13                  -1  2   1993728  doclayout_yolo.nn.modules.block.C2f          [960, 384, 2]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  doclayout_yolo.nn.modules.conv.Concat        [1]
#  16                  -1  2    517632  doclayout_yolo.nn.modules.block.C2f          [576, 192, 2]
#  17                  -1  1    332160  doclayout_yolo.nn.modules.conv.Conv          [192, 192, 3, 2]
#  18            [-1, 13]  1         0  doclayout_yolo.nn.modules.conv.Concat        [1]
#  19                  -1  2    831744  doclayout_yolo.nn.modules.block.C2fCIB       [576, 384, 2, True]
#  20                  -1  1    152448  doclayout_yolo.nn.modules.block.SCDown       [384, 384, 3, 2]
#  21            [-1, 10]  1         0  doclayout_yolo.nn.modules.conv.Concat        [1]
#  22                  -1  2   1911168  doclayout_yolo.nn.modules.block.C2fCIB       [960, 576, 2, True]
#  23        [16, 19, 22]  1   2289082  doclayout_yolo.nn.modules.head.v10Detect     [7, [192, 384, 576]]
# YOLOv10m-doclayout summary: 636 layers, 19970122 parameters, 19970106 gradients, 68.0 GFLOPs
#
# Transferred 1039/1051 items from pretrained weights
# DDP: debug command /usr/bin/python3 -m torch.distributed.run --nproc_per_node 2 --master_port 42099 /root/.config/Ultralytics/DDP/_temp_j_b9h52e135816081696640.py
#
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# Ultralytics YOLOv0.0.2 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#                                                             CUDA:1 (Tesla T4, 14913MiB)
# [W605 06:13:24.252739209 Utils.hpp:166] Warning: Environment variable NCCL_BLOCKING_WAIT is deprecated; use TORCH_NCCL_BLOCKING_WAIT instead (function operator())
# 2026-06-05 06:13:24.489928: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780640004.514091     119 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780640004.522978     119 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1780640004.543644     119 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780640004.543694     119 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780640004.543701     119 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780640004.543710     119 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [W605 06:13:29.274272286 Utils.hpp:166] Warning: Environment variable NCCL_BLOCKING_WAIT is deprecated; use TORCH_NCCL_BLOCKING_WAIT instead (function operator())
# TensorBoard: Start with 'tensorboard --logdir rukopys_v3_clean_gold_plus_rare_silver/yolov10doclayout_yolo_small_/kaggle/working/rukopys_dataset_v3.yaml_epoch100_imgsz1280_bs8_pretrain_unknown', view at http://localhost:6006/
# Overriding model.yaml nc=10 with nc=7
# Transferred 1039/1051 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=self.amp)
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=self.amp)
# [rank0]:[W605 06:13:31.387024303 Utils.hpp:112] Warning: Environment variable NCCL_BLOCKING_WAIT is deprecated; use TORCH_NCCL_BLOCKING_WAIT instead (function operator())
# [rank1]:[W605 06:13:31.387034726 Utils.hpp:112] Warning: Environment variable NCCL_BLOCKING_WAIT is deprecated; use TORCH_NCCL_BLOCKING_WAIT instead (function operator())
# train: Scanning /kaggle/working/layout_data/rukopys_v3/labels... 2070 images, 0
# train: WARNING ⚠️ /kaggle/working/layout_data/rukopys_v3/images/scanned_4341a85a-d4ef-5a54-a1d0-0f68b2f89f57.jpg: 1 duplicate labels removed
# train: New cache created: /kaggle/working/layout_data/rukopys_v3/labels.cache
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/data/augment.py:846: UserWarning: Argument(s) 'quality_lower' are not valid for transform ImageCompression
#   A.ImageCompression(quality_lower=75, p=0.0),
# /usr/local/lib/python3.12/dist-packages/albumentations/core/composition.py:331: UserWarning: Got processor for bboxes, but no transform to process it.
#   self._set_keys()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /kaggle/working/layout_data/rukopys_v3/labels... 70 images, 0 back/kaggle/working/DocLayout-YOLO/doclayout_yolo/data/augment.py:846: UserWarning: Argument(s) 'quality_lower' are not valid for transform ImageCompression
#   A.ImageCompression(quality_lower=75, p=0.0),
# /usr/local/lib/python3.12/dist-packages/albumentations/core/composition.py:331: UserWarning: Got processor for bboxes, but no transform to process it.
#   self._set_keys()
# val: Scanning /kaggle/working/layout_data/rukopys_v3/labels... 181 images, 0 bac/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# val: Scanning /kaggle/working/layout_data/rukopys_v3/labels... 257 images, 0 bac
# val: New cache created: /kaggle/working/layout_data/rukopys_v3/labels.cache
# optimizer: Adam(lr=0.001, momentum=0.9) with parameter groups 171 weight(decay=0.0), 184 weight(decay=0.0005), 183 bias(decay=0.0)
# TensorBoard: WARNING ⚠️ TensorBoard graph visualization failure 'NoneType' object is not callable
# Image sizes 1280 train, 1280 val
# Using 4 dataloader workers
# Logging results to rukopys_v3_clean_gold_plus_rare_silver/yolov10doclayout_yolo_small_/kaggle/working/rukopys_dataset_v3.yaml_epoch100_imgsz1280_bs8_pretrain_unknown
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       1/100      14.3G      1.667      1.892      1.238      1.622      2.563
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.486      0.307      0.297      0.183
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       2/100      14.2G      1.545      1.338      1.182       1.54      1.597
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.554      0.408      0.406      0.247
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       3/100      14.1G      1.539      1.229      1.203      1.544      1.421
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.509      0.479      0.471      0.289
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       4/100      14.2G      1.513      1.175      1.171      1.521       1.34
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.447      0.522       0.49      0.296
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       5/100      14.1G       1.51      1.135      1.182      1.513      1.283
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.592      0.571      0.552      0.333
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       6/100      14.1G      1.525      1.153      1.205      1.534      1.291
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998       0.64      0.558       0.57      0.358
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       7/100        14G      1.489      1.094      1.182      1.502      1.211
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.633      0.548      0.583      0.362
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       8/100      14.2G       1.51      1.099      1.188      1.526      1.209
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.568       0.58      0.571      0.353
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       9/100      14.2G       1.47      1.058      1.167       1.49      1.158
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.558      0.594      0.599       0.36
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      10/100      14.2G      1.464       1.01      1.155      1.477      1.113
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.602      0.591       0.58      0.367
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      11/100      14.1G      1.446      1.009      1.154      1.464        1.1
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998       0.61      0.643      0.628      0.402
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      12/100      14.2G      1.446      1.001      1.161      1.459      1.087
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.612      0.618      0.623      0.382
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      13/100      14.1G      1.439     0.9797      1.151       1.46      1.053
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.642      0.578      0.626      0.384
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      14/100      14.1G      1.449     0.9988      1.156      1.477      1.077
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.641      0.636      0.646      0.413
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      15/100      14.2G      1.442     0.9763      1.152      1.462      1.045
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.605       0.61      0.643      0.411
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      16/100      14.2G      1.449     0.9813      1.162      1.471      1.053
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.672      0.621      0.646       0.39
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      17/100        14G      1.426      0.993      1.178      1.448      1.063
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.607      0.595      0.606      0.394
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      18/100      14.4G       1.43     0.9679      1.152      1.453      1.044
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.665      0.615      0.663      0.407
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      19/100      14.2G      1.419     0.9495       1.15      1.441       1.01
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.664      0.589      0.647      0.402
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      20/100      14.2G        1.4     0.9234       1.14      1.411      0.988
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.622      0.645      0.645      0.395
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      21/100      14.2G       1.42     0.9256      1.129      1.434     0.9836
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998       0.64      0.633      0.642      0.416
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      22/100      14.1G      1.424     0.9137      1.141      1.439     0.9606
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.608      0.568      0.585       0.38
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      23/100      14.2G       1.39     0.9111      1.134      1.414     0.9734
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.597       0.68      0.645      0.402
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      24/100      14.2G      1.399     0.8939      1.136      1.414     0.9394
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.766      0.566       0.65      0.416
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      25/100      14.2G      1.381     0.8848      1.125      1.398     0.9287
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.622      0.646      0.647      0.405
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      26/100      14.2G      1.417     0.9097      1.139      1.435     0.9423
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.659      0.632      0.668      0.427
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      27/100      14.2G      1.408     0.8935      1.137      1.431     0.9447
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.662      0.665      0.661      0.421
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      28/100      14.2G       1.37     0.8656       1.12      1.392     0.9047
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.756      0.638      0.693      0.431
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      29/100      14.2G       1.36     0.8812      1.131      1.384     0.9157
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.671      0.701      0.707      0.461
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      30/100      14.2G       1.38     0.8779      1.123      1.404     0.9176
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.712      0.658       0.69       0.44
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      31/100      14.2G      1.362     0.8544      1.119      1.389     0.8869
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.707       0.61      0.658      0.427
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      32/100      14.2G      1.365     0.8664      1.127      1.391     0.9086
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.584      0.689      0.644      0.419
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      33/100      14.1G      1.363     0.8401      1.117      1.382     0.8733
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.728      0.628      0.689      0.443
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      34/100      14.2G      1.367     0.8232      1.117      1.386     0.8675
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.673       0.58      0.633      0.405
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      35/100      14.2G      1.356     0.8431      1.124      1.377     0.8725
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.657      0.673      0.688      0.446
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      36/100      14.2G      1.333     0.8192      1.116      1.357     0.8542
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.677      0.664      0.652      0.426
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      37/100      14.2G      1.348     0.8365      1.108      1.365     0.8822
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.671      0.661      0.671      0.445
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      38/100      14.2G      1.349     0.8387      1.105      1.363     0.8798
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998       0.68       0.65      0.663      0.433
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      39/100      14.2G      1.354     0.8227      1.116      1.377     0.8454
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.714      0.654        0.7      0.451
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      40/100      14.2G      1.333      0.808      1.093      1.356     0.8261
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.729      0.662      0.711      0.469
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      41/100      14.2G      1.346     0.8087      1.096      1.373     0.8435
# ...
#   with torch.cuda.amp.autocast(self.amp):
#      92/100      14.2G      1.072     0.5454     0.9698      1.089     0.5084
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998       0.75      0.652      0.724      0.486
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      93/100      14.2G       1.06     0.5343     0.9624      1.078     0.4966
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.715      0.667      0.684      0.453
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      94/100      14.2G       1.06     0.5393     0.9631      1.079     0.5029
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.658      0.736       0.71      0.467
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      95/100      14.2G      1.055     0.5343     0.9623      1.073     0.4969
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.692      0.711      0.718      0.469
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      96/100      14.2G      1.027     0.5144     0.9603       1.05      0.474
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998       0.72      0.686      0.709      0.458
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      97/100      14.2G      1.012     0.5131     0.9515      1.028     0.4731
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998       0.73      0.684       0.71       0.47
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      98/100      14.2G      1.031     0.5308     0.9603      1.055     0.4922
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.708      0.718      0.705      0.468
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#      99/100      14.2G      1.033     0.5219     0.9532      1.055     0.4857
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.739      0.678       0.71      0.473
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#   0%|          | 0/259 [00:00<?, ?it/s]/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# /kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py:380: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#     100/100      14.2G      1.023     0.5158      0.946      1.041     0.4763
#                  Class     Images  Instances      Box(P          R      mAP50  m
# 257
#                    all        257       4998      0.719       0.68      0.701      0.466
#
# 100 epochs completed in 8.415 hours.
# Optimizer stripped from rukopys_v3_clean_gold_plus_rare_silver/yolov10doclayout_yolo_small_/kaggle/working/rukopys_dataset_v3.yaml_epoch100_imgsz1280_bs8_pretrain_unknown/weights/last.pt, 40.6MB
# Optimizer stripped from rukopys_v3_clean_gold_plus_rare_silver/yolov10doclayout_yolo_small_/kaggle/working/rukopys_dataset_v3.yaml_epoch100_imgsz1280_bs8_pretrain_unknown/weights/best.pt, 40.6MB
#
# Validating rukopys_v3_clean_gold_plus_rare_silver/yolov10doclayout_yolo_small_/kaggle/working/rukopys_dataset_v3.yaml_epoch100_imgsz1280_bs8_pretrain_unknown/weights/best.pt...
# Ultralytics YOLOv0.0.2 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#                                                             CUDA:1 (Tesla T4, 14913MiB)
# YOLOv10m-doclayout summary (fused): 465 layers, 19925434 parameters, 0 gradients
# [rank0]: Traceback (most recent call last):
# [rank0]:   File "/root/.config/Ultralytics/DDP/_temp_j_b9h52e135816081696640.py", line 12, in <module>
# [rank0]:     results = trainer.train()
# [rank0]:               ^^^^^^^^^^^^^^^
# [rank0]:   File "/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py", line 214, in train
# [rank0]:     self._do_train(world_size)
# [rank0]:   File "/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py", line 473, in _do_train
# [rank0]:     self.final_eval()
# [rank0]:   File "/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py", line 630, in final_eval
# [rank0]:     self.metrics = self.validator(model=f)
# [rank0]:                    ^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/validator.py", line 170, in __call__
# [rank0]:     model.warmup(imgsz=(1 if pt else self.args.batch, 3, imgsz, imgsz))  # warmup
# [rank0]:     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/kaggle/working/DocLayout-YOLO/doclayout_yolo/nn/autobackend.py", line 586, in warmup
# [rank0]:     self.forward(im)  # warmup
# [rank0]:     ^^^^^^^^^^^^^^^^
# [rank0]:   File "/kaggle/working/DocLayout-YOLO/doclayout_yolo/nn/autobackend.py", line 420, in forward
# [rank0]:     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
# [rank0]:         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
# [rank0]:     return self._call_impl(*args, **kwargs)
# [rank0]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
# [rank0]:     return forward_call(*args, **kwargs)
# [rank0]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/kaggle/working/DocLayout-YOLO/doclayout_yolo/nn/tasks.py", line 96, in forward
# [rank0]:     return self.predict(x, *args, **kwargs)
# [rank0]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/kaggle/working/DocLayout-YOLO/doclayout_yolo/nn/tasks.py", line 114, in predict
# [rank0]:     return self._predict_once(x, profile, visualize, embed)
# [rank0]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/kaggle/working/DocLayout-YOLO/doclayout_yolo/nn/tasks.py", line 136, in _predict_once
# [rank0]:     x = m(x)  # run
# [rank0]:         ^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
# [rank0]:     return self._call_impl(*args, **kwargs)
# [rank0]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
# [rank0]:     return forward_call(*args, **kwargs)
# [rank0]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/kaggle/working/DocLayout-YOLO/doclayout_yolo/nn/modules/g2l_crm.py", line 114, in forward
# [rank0]:     y.append(m(y[-1]))
# [rank0]:              ^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
# [rank0]:     return self._call_impl(*args, **kwargs)
# [rank0]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
# [rank0]:     return forward_call(*args, **kwargs)
# [rank0]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/kaggle/working/DocLayout-YOLO/doclayout_yolo/nn/modules/g2l_crm.py", line 77, in forward
# [rank0]:     return x + self.cv2(self.dilated_block(self.cv1(x))) if self.add else self.cv2(self.dilated_block(self.cv1(x)))
# [rank0]:                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
# [rank0]:     return self._call_impl(*args, **kwargs)
# [rank0]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
# [rank0]:     return forward_call(*args, **kwargs)
# [rank0]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/kaggle/working/DocLayout-YOLO/doclayout_yolo/nn/modules/g2l_crm.py", line 43, in forward
# [rank0]:     dx = [self.dilated_conv(x, d) for d in self.dilation]
# [rank0]:           ^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/kaggle/working/DocLayout-YOLO/doclayout_yolo/nn/modules/g2l_crm.py", line 39, in dilated_conv
# [rank0]:     return act(bn(F.conv2d(x, weight, stride=1, padding=padding, dilation=dilation)))
# [rank0]:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]: TypeError: 'NoneType' object is not callable
# [rank0]:[W605 14:38:45.566939987 ProcessGroupNCCL.cpp:1553] Warning: WARNING: destroy_process_group() was not called before program exit, which can leak resources. For more info, please see https://pytorch.org/docs/stable/distributed.html#shutdown (function operator())
# E0605 14:38:47.829000 113 torch/distributed/elastic/multiprocessing/api.py:984] failed (exitcode: 1) local_rank: 0 (pid: 119) of binary: /usr/bin/python3
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.12/dist-packages/torch/distributed/run.py", line 995, in <module>
#     main()
#   File "/usr/local/lib/python3.12/dist-packages/torch/distributed/elastic/multiprocessing/errors/__init__.py", line 362, in wrapper
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/distributed/run.py", line 991, in main
#     run(args)
#   File "/usr/local/lib/python3.12/dist-packages/torch/distributed/run.py", line 982, in run
#     elastic_launch(
#   File "/usr/local/lib/python3.12/dist-packages/torch/distributed/launcher/api.py", line 170, in __call__
#     return launch_agent(self._config, self._entrypoint, list(args))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/distributed/launcher/api.py", line 317, in launch_agent
#     raise ChildFailedError(
# torch.distributed.elastic.multiprocessing.errors.ChildFailedError:
# ============================================================
# /root/.config/Ultralytics/DDP/_temp_j_b9h52e135816081696640.py FAILED
# ------------------------------------------------------------
# Failures:
#   <NO_OTHER_FAILURES>
# ------------------------------------------------------------
# Root Cause (first observed failure):
# [0]:
#   time      : 2026-06-05_14:38:47
#   host      : 6af91f9b32d6
#   rank      : 0 (local_rank: 0)
#   exitcode  : 1 (pid: 119)
#   error_file: <N/A>
#   traceback : To enable traceback see: https://pytorch.org/docs/stable/elastic/errors.html
# ============================================================
# Traceback (most recent call last):
#   File "/kaggle/working/DocLayout-YOLO/train.py", line 63, in <module>
#     results = model.train(
#               ^^^^^^^^^^^^
#   File "/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/model.py", line 660, in train
#     self.trainer.train()
#   File "/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py", line 209, in train
#     raise e
#   File "/kaggle/working/DocLayout-YOLO/doclayout_yolo/engine/trainer.py", line 207, in train
#     subprocess.run(cmd, check=True)
#   File "/usr/lib/python3.12/subprocess.py", line 571, in run
#     raise CalledProcessError(retcode, process.args,
# subprocess.CalledProcessError: Command '['/usr/bin/python3', '-m', 'torch.distributed.run', '--nproc_per_node', '2', '--master_port', '42099', '/root/.config/Ultralytics/DDP/_temp_j_b9h52e135816081696640.py']' returned non-zero exit status 1.
